# %%
import numpy as np

# %%
array = np.array([[1, 2, 3], [4, 5, 6]])
array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#adição de uma nova linha
soma = np.add(array, 10)
soma

sub = np.subtract(array, 2)
sub
# Out:
# array([[-1,  0,  1],
#        [ 2,  3,  4]])

# %%
prod = np.multiply(array, 2)
prod
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
div = np.divide(array, 2)
div
# Out:
# array([[0.5, 1. , 1.5],
#        [2. , 2.5, 3. ]])
