# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.5.3'

# %%
arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 20
multiplicacao = arr * 2
media = arr.mean()

# %%
print(soma)
print(multiplicacao)
print(media)
# Out:
# [21 22 23 24 25]
# [ 2  4  6  8 10]
# 3.0
